# %%
import sagemaker
import boto3
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# /tmp/ipykernel_46872/3092795126.py in <module>
#       3
#       4 iam_client = boto3.client('iam')
# ----> 5 role = iam_client.get_role(RoleName='arn:aws:iam::195943313158:role/local-run')['Role']['Arn']
#       6 sess = sagemaker.Session()
#
# ~/miniconda3/envs/aim/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     528                 )
#     529             # The "self" in this scope is referring to the BaseClient.
# --> 530             return self._make_api_call(operation_name, kwargs)
#     531
#     532         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda3/envs/aim/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     942             apply_request_checksum(request_dict)
# ...

# %%
try:
    role = sagemaker.get_execution_role()
except ValueError:
    iam = boto3.client('iam')
    role = iam.get_role(RoleName='arn:aws:iam::195943313158:role/local-run')['Role']['Arn']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_46872/1875573663.py in <module>
#       1 try:
# ----> 2     role = sagemaker.get_execution_role()
#       3 except ValueError:
#
# ~/miniconda3/envs/aim/lib/python3.7/site-packages/sagemaker/session.py in get_execution_role(sagemaker_session)
#    4728     if not sagemaker_session:
# -> 4729         sagemaker_session = Session()
#    4730     arn = sagemaker_session.get_caller_identity_arn()
#
# ~/miniconda3/envs/aim/lib/python3.7/site-packages/sagemaker/session.py in __init__(self, boto_session, sagemaker_client, sagemaker_runtime_client, sagemaker_featurestore_runtime_client, default_bucket, settings)
#     131             sagemaker_runtime_client=sagemaker_runtime_client,
# --> 132             sagemaker_featurestore_runtime_client=sagemaker_featurestore_runtime_client,
#     133         )
#
# ...
